# %% [markdown]
# # Life Expectancy vs. Adult Mortality Rates in 2015
#
# We aim to learn more about how life expectancy may affect adult mortality rates, and if so, how does it.

# %%
import pandas as pd

dataframe = pd.read_csv("variables_check.csv")
dataframe
# Out:
#                      Group Members:  Unnamed: 1  Unnamed: 2  \
# 0           Rounak Rai (1st Period)         NaN         NaN
# 1    Sankalp Prashanth (5th Period)         NaN         NaN
# 2            Felix Gao (6th Period)         NaN         NaN
# 3                               NaN         NaN         NaN
# 4                          Source:          NaN         NaN
# ..                              ...         ...         ...
# 178                             NaN         NaN         NaN
# 179                             NaN         NaN         NaN
# 180                             NaN         NaN         NaN
# 181                             NaN         NaN         NaN
# 182                             NaN         NaN         NaN
#
#                                 Country  Year      Status  Life expectancy   \
# 0                           Afghanistan  2015  Developing              65.0
# 1                               Albania  2015  Developing              77.8
# ...
